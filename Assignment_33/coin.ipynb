# %%
import cv2
import numpy as np 
import matplotlib.pyplot as plt

# %%
img = cv2.imread("input/c10.jpg" , cv2.IMREAD_GRAYSCALE)
plt.imshow( img , cmap="gray")
plt.axis("off")
plt.show()

# %%
_ , thresh = cv2.threshold(img , 10 , 255 , cv2.THRESH_BINARY)
plt.imshow( thresh , cmap="gray")
plt.axis("off")
plt.show()

# %%
# noise reduction , ba blur / median 
# threshold zadan
# filter gozari rooye size

# %%
contours , hierarchy = cv2.findContours(thresh , cv2.RETR_EXTERNAL , cv2.CHAIN_APPROX_SIMPLE) # ax midim , liste contour ha ro mide 
print(len(contours))
print(hierarchy)
# agar -1 bashe yani contour external hast 
# oon khati ke index akharesh 1 hastan seke han  
coins = img.copy()
count = 0
array = []
for contour in contours :
    if cv2.contourArea(contour) > 1000 :
        x , y , w , h = cv2.boundingRect(contour)
        cv2.rectangle(coins , (x,y) , (x+w , y+h) , (127 , 127 , 127) , 3)
        print([x , y , x+w , y+h])
        count+=1
print(count)

# plt.axis("off")  
plt.imshow(coins , cmap="gray") 
plt.show()
# Out:
# 32
# [[[ 1 -1 -1 -1]
#   [ 2  0 -1 -1]
#   [ 3  1 -1 -1]
#   [ 4  2 -1 -1]
#   [ 5  3 -1 -1]
#   [ 6  4 -1 -1]
#   [ 7  5 -1 -1]
#   [ 8  6 -1 -1]
#   [ 9  7 -1 -1]
#   [10  8 -1 -1]
#   [11  9 -1 -1]
#   [12 10 -1 -1]
#   [13 11 -1 -1]
#   [14 12 -1 -1]
#   [15 13 -1 -1]
#   [16 14 -1 -1]
#   [17 15 -1 -1]
#   [18 16 -1 -1]
#   [19 17 -1 -1]
#   [20 18 -1 -1]
#   [21 19 -1 -1]
#   [22 20 -1 -1]
#   [23 21 -1 -1]
#   [24 22 -1 -1]
#   [25 23 -1 -1]
#   [26 24 -1 -1]
#   [27 25 -1 -1]
#   [28 26 -1 -1]
#   [29 27 -1 -1]
#   [30 28 -1 -1]
#   [31 29 -1 -1]
#   [-1 30 -1 -1]]]
# [212, 109, 566, 455]
# 1

# %%
width , height = img.shape()
print(width , height )

def MyContourFinder(image  ) :

    for i in range(width):
        for j in range (height):
            ...
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 width , height = img.shape()
#       2 print(width , height )
#       4 def MyContourFinder(image  ) :
#
# TypeError: 'tuple' object is not callable
