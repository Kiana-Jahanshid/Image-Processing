# %%
import cv2
import numpy as np 
import matplotlib.pyplot as plt

# %%
img = cv2.imread("rose.jpg" , cv2.IMREAD_GRAYSCALE)
img1 = cv2.imread("w.jpg"   , cv2.IMREAD_GRAYSCALE)
img2 = cv2.imread("spider.png" , cv2.IMREAD_GRAYSCALE)
img3 = np.zeros([100,200] , dtype=np.uint8)

plt.imshow( img1 , cmap="gray")
#plt.axis("off")
plt.show()

# %%
_ , thresh = cv2.threshold(img1 , 127 , 255 , cv2.THRESH_BINARY)
plt.imshow( thresh , cmap="gray")
plt.show()

# %%
# image , mode , method , 
# mode : """EXTERNAL contour""" : yani contours haye birooni ro mide ba ma 
#      : """LIST"""              : all contours ro barmigardoone
#      : """TREE"""              : migam kodoom contour , dakhele kodoom contour hast . hame contour ha ro behemoon mide ,  nesbate pedar farzandi shoono h am be ma miide 


# method : 
# vaghti contour return mikone chia return mikone ?
# CHAIN_APPROX_NONE :   STORES ALL THE CONTOURS POINTS .  tamame pixel haye rec ro barmigardoone --------> PRINT KON CONTOURS RO === TAK TAK PIXEL H
# CHAIN_APPROX_SIMPLE :  noghate atraf ya gooshe rectangle ro mide  , faghat 4 NOGHTE gooshe ro mide 
# CHAIN_APPROX_TC89_L1 : 
# CHAIN_APPROX_TC89_KCOS : 


contours  , _ =  cv2.findContours(thresh , cv2.RETR_EXTERNAL , cv2.CHAIN_APPROX_SIMPLE)
res = img1.copy()
counter = 0 
for contour in contours :
    if cv2.contourArea(contour) > 1000  :
        counter+=1
        x,y,w,h = cv2.boundingRect(contour)
        print(contours)
        cv2.rectangle(res , (x,y) , (x+w , y+h) , (255,255,255) , 3) #bounding box 
        continue
print(counter)
plt.imshow(res , cmap="gray")
# Out:
# (array([[[ 785, 1199]]], dtype=int32), array([[[1418, 1197]],
#
#        [[1418, 1198]]], dtype=int32), array([[[1118, 1195]],
#
#        [[1118, 1196]]], dtype=int32), array([[[ 710, 1195]],
#
#        [[ 711, 1195]]], dtype=int32), array([[[1420, 1193]],
#
#        [[1420, 1194]]], dtype=int32), array([[[ 779, 1193]],
#
#        [[ 779, 1194]],
#
#        [[ 781, 1196]],
#
#        [[ 782, 1196]],
#
#        [[ 782, 1195]],
#
#        [[ 781, 1194]],
#
#        [[ 780, 1194]]], dtype=int32), array([[[ 679, 1191]],
#
#        [[ 679, 1192]],
#
#        [[ 680, 1191]],
#
#        [[ 681, 1192]],
#
#        [[ 681, 1193]],
#
#        [[ 682, 1193]],
#
#        [[ 682, 1192]],
#
#        [[ 681, 1192]],
#
#        [[ 680, 1191]]], dtype=int32), array([[[ 838, 1187]]], dtype=int32), array([[[1076, 1184]]], dtype=int32), array([[[ 768, 1182]],
#
#        [[ 767, 1183]],
#
#        [[ 767, 1184]],
#
#        [[ 772, 1189]],
#
#        [[ 773, 1189]],
#
#        [[ 774, 1190]],
#
#        [[ 775, 1190]],
#
#        [[ 777, 1192]],
#
#        [[ 774, 1189]],
#
#        [[ 774, 1188]],
#
#        [[ 773, 1187]],
#
#        [[ 773, 1186]],
#
#        [[ 769, 1182]]], dtype=int32), array([[[ 741, 1181]],
#
#        [[ 741, 1182]]], dtype=int32), array([[[1294, 1179]],
#
#        [[1294, 1181]],
#
#        [[1295, 1182]],
#
#        [[1295, 1185]],
#
#        [[1296, 1186]],
#
#        [[1296, 1188]],
#
#        [[1296, 1183]],
#
#        [[1295, 1182]],
#
#        [[1295, 1179]]], dtype=int32), array([[[ 733, 1177]],
#
#        [[ 733, 1178]]], dtype=int32), array([[[1089, 1175]]], dtype=int32), array([[[ 729, 1173]],
#
#        [[ 729, 1174]]], dtype=int32), array([[[ 566, 1171]]], dtype=int32), array([[[ 571, 1161]],
#
#        [[ 570, 1162]],
#
#        [[ 570, 1163]],
#
#        [[ 573, 1163]],
#
#        [[ 574, 1162]],
#
#        [[ 573, 1161]]], dtype=int32), array([[[1324, 1157]],
#
#        [[1323, 1158]],
#
#        [[1324, 1159]],
#
#        [[1325, 1158]]], dtype=int32), array([[[1134, 1157]],
#
#        [[1135, 1158]],
#
#        [[1135, 1159]],
#
#        [[1137, 1159]],
#
#        [[1138, 1158]],
#
#        [[1137, 1158]],
#
#        [[1136, 1157]]], dtype=int32), array([[[1326, 1156]]], dtype=int32), array([[[1014, 1151]],
#
#        [[1014, 1153]],
#
#        [[1015, 1154]],
#
#        [[1015, 1155]],
#
#        [[1016, 1155]],
#
#        [[1016, 1154]],
#
#        [[1014, 1152]]], dtype=int32), array([[[1078, 1150]],
#
#        [[1078, 1153]],
#
#        [[1080, 1151]],
#
#        [[1079, 1150]]], dtype=int32), array([[[ 591, 1149]],
#
#        [[ 591, 1151]],
#
#        [[ 592, 1151]],
#
#        [[ 593, 1150]],
#
#        [[ 594, 1150]],
#
#        [[ 594, 1149]]], dtype=int32), array([[[ 781, 1147]],
#
#        [[ 783, 1147]],
#
#        [[ 784, 1148]],
#
#        [[ 787, 1148]],
#
#        [[ 784, 1148]],
#
#        [[ 783, 1147]]], dtype=int32), array([[[1382, 1145]]], dtype=int32), array([[[ 890, 1143]],
#
#        [[ 892, 1145]],
#
#        [[ 894, 1145]],
#
#        [[ 895, 1146]],
#
#        [[ 897, 1144]],
#
#        [[ 896, 1145]],
#
#        [[ 894, 1145]],
#
#        [[ 892, 1143]]], dtype=int32), array([[[ 885, 1142]],
#
#        [[ 887, 1142]],
#
#        [[ 888, 1143]],
#
#        [[ 888, 1142]]], dtype=int32), array([[[1178, 1141]],
#
#        [[1177, 1142]],
#
#        [[1175, 1142]],
#
#        [[1175, 1143]],
#
#        [[1174, 1144]],
#
#        [[1169, 1144]],
#
#        [[1168, 1145]],
#
#        [[1164, 1145]],
#
#        [[1163, 1146]],
#
#        [[1166, 1146]],
#
#        [[1167, 1145]],
#
#        [[1174, 1145]],
#
#        [[1175, 1144]],
#
#        [[1179, 1144]],
#
#        [[1180, 1143]],
#
#        [[1181, 1143]],
#
#        [[1181, 1142]],
#
#        [[1180, 1141]]], dtype=int32), array([[[1410, 1139]],
#
#        [[1410, 1140]]], dtype=int32), array([[[1079, 1138]],
#
#        [[1079, 1140]],
#
#        [[1081, 1140]],
#
#        [[1081, 1139]],
#
#        [[1080, 1138]]], dtype=int32), array([[[ 909, 1138]],
#
#        [[ 908, 1139]],
#
#        [[ 908, 1142]],
#
#        [[ 907, 1143]],
#
#        [[ 907, 1144]],
#
#        [[ 908, 1143]],
#
#        [[ 908, 1141]],
#
#        [[ 909, 1140]]], dtype=int32), array([[[ 663, 1138]],
#
#        [[ 663, 1140]],
#
#        [[ 664, 1140]],
#
#        [[ 664, 1139]]], dtype=int32), array([[[ 959, 1137]]], dtype=int32), array([[[1084, 1136]],
#
#        [[1084, 1138]],
#
#        [[1085, 1139]],
#
#        [[1085, 1136]]], dtype=int32), array([[[1088, 1135]],
#
#        [[1088, 1137]],
#
#        [[1089, 1137]],
#
#        [[1089, 1135]]], dtype=int32), array([[[ 919, 1135]],
#
#        [[ 918, 1136]],
#
#        [[ 917, 1136]],
#
#        [[ 919, 1136]],
#
#        [[ 920, 1135]],
#
#        [[ 921, 1135]]], dtype=int32), array([[[ 926, 1133]],
#
#        [[ 925, 1134]],
#
#        [[ 923, 1134]],
#
#        [[ 924, 1135]]], dtype=int32), array([[[1014, 1132]],
#
#        [[1015, 1132]]], dtype=int32), array([[[ 929, 1131]],
#
#        [[ 929, 1132]],
#
#        [[ 931, 1132]],
#
#        [[ 930, 1131]]], dtype=int32), array([[[1114, 1130]],
#
#        [[1115, 1131]],
#
#        [[1115, 1130]]], dtype=int32), array([[[1006, 1128]],
#
#        [[1005, 1129]],
#
#        [[1006, 1130]],
#
#        [[1006, 1131]],
#
#        [[1007, 1132]],
#
#        [[1007, 1134]],
#
#        [[1008, 1135]],
#
#        [[1007, 1134]],
#
#        [[1007, 1130]],
#
#        [[1006, 1129]]], dtype=int32), array([[[1003, 1128]]], dtype=int32), array([[[ 995, 1125]],
#
#        [[ 995, 1126]],
#
#        [[ 996, 1127]],
#
#        [[ 999, 1127]],
#
#        [[ 999, 1126]],
#
#        [[ 998, 1125]]], dtype=int32), array([[[ 989, 1124]],
#
#        [[ 989, 1125]],
#
#        [[ 992, 1125]],
#
#        [[ 990, 1125]]], dtype=int32), array([[[ 952, 1122]],
#
#        [[ 950, 1124]],
#
#        [[ 948, 1124]],
#
#        [[ 946, 1126]],
#
#        [[ 945, 1126]],
#
#        [[ 944, 1127]],
#
#        [[ 943, 1127]],
#
#        [[ 942, 1128]],
#
#        [[ 941, 1128]],
#
#        [[ 940, 1129]],
#
#        [[ 937, 1129]],
#
#        [[ 936, 1130]],
#
#        [[ 937, 1131]],
#
#        [[ 938, 1130]],
#
#        [[ 939, 1130]],
#
#        [[ 940, 1129]],
#
#        [[ 944, 1129]],
#
#        [[ 945, 1128]],
#
#        [[ 946, 1128]],
#
#        [[ 948, 1126]],
#
#        [[ 949, 1126]],
#
#        [[ 951, 1124]],
#
#        [[ 953, 1124]],
#
#        [[ 954, 1125]],
#
#        [[ 954, 1126]],
#
#        [[ 955, 1126]],
#
#        [[ 956, 1127]],
#
#        [[ 956, 1128]],
#
#        [[ 956, 1127]],
#
#        [[ 953, 1124]],
#
#        [[ 953, 1123]]], dtype=int32), array([[[1124, 1121]]], dtype=int32), array([[[ 930, 1121]],
#
#        [[ 929, 1122]],
#
#        [[ 930, 1122]]], dtype=int32), array([[[ 950, 1119]],
#
#        [[ 951, 1120]]], dtype=int32), array([[[ 978, 1118]],
#
#        [[ 980, 1118]]], dtype=int32), array([[[ 925, 1118]]], dtype=int32), array([[[1174, 1117]],
#
#        [[1174, 1118]],
#
#        [[1175, 1119]],
#
#        [[1175, 1121]],
#
#        [[1176, 1122]],
#
#        [[1176, 1123]],
#
#        [[1176, 1122]],
#
#        [[1175, 1121]],
#
#        [[1175, 1119]],
#
#        [[1174, 1118]]], dtype=int32), array([[[ 982, 1117]],
#
#        [[ 983, 1117]]], dtype=int32), array([[[ 789, 1117]],
#
#        [[ 791, 1119]]], dtype=int32), array([[[ 986, 1116]],
#
#        [[ 987, 1116]]], dtype=int32), array([[[ 935, 1115]]], dtype=int32), array([[[1287, 1114]],
#
#        [[1286, 1115]],
#
#        [[1286, 1116]],
#
#        [[1285, 1117]],
#
#        [[1285, 1118]],
#
#        [[1286, 1119]],
#
#        [[1286, 1121]],
#
#        [[1286, 1120]],
#
#        [[1288, 1118]],
#
#        [[1288, 1117]],
#
#        [[1289, 1116]],
#
#        [[1287, 1116]],
#
#        [[1286, 1115]]], dtype=int32), array([[[ 947, 1114]]], dtype=int32), array([[[ 953, 1113]],
#
#        [[ 953, 1114]],
#
#        [[ 955, 1114]],
#
#        [[ 955, 1113]]], dtype=int32), array([[[ 726, 1113]]], dtype=int32), array([[[ 961, 1112]],
#
#        [[ 962, 1113]],
#
#        [[ 963, 1112]]], dtype=int32), array([[[1316, 1109]],
#
#        [[1316, 1110]]], dtype=int32), array([[[1216, 1106]],
#
#        [[1217, 1106]]], dtype=int32), array([[[1001, 1105]]], dtype=int32), array([[[1227, 1104]],
#
#        [[1226, 1105]],
#
#        [[1227, 1106]],
#
#        [[1228, 1106]],
#
#        [[1229, 1107]],
#
#        [[1229, 1105]],
#
#        [[1228, 1104]]], dtype=int32), array([[[ 881, 1104]]], dtype=int32), array([[[1208, 1102]]], dtype=int32), array([[[1265, 1099]]], dtype=int32), array([[[ 938, 1099]],
#
#        [[ 939, 1099]]], dtype=int32), array([[[ 822, 1098]]], dtype=int32), array([[[1400, 1097]],
#
#        [[1401, 1098]],
#
#        [[1401, 1100]],
#
#        [[1402, 1100]],
#
#        [[1401, 1099]],
#
#        [[1401, 1098]]], dtype=int32), array([[[1397, 1097]],
#
#        [[1397, 1099]]], dtype=int32), array([[[1194, 1097]],
#
#        [[1197, 1097]]], dtype=int32), array([[[1168, 1097]],
#
#        [[1169, 1098]],
#
#        [[1169, 1101]],
#
#        [[1170, 1102]],
#
#        [[1170, 1106]],
#
#        [[1171, 1107]],
#
#        [[1171, 1110]],
#
#        [[1172, 1111]],
#
#        [[1172, 1113]],
#
#        [[1173, 1114]],
#
#        [[1173, 1115]],
#
#        [[1173, 1112]],
#
#        [[1172, 1111]],
#
#        [[1172, 1110]],
#
#        [[1171, 1109]],
#
#        [[1171, 1106]],
#
#        [[1170, 1105]],
#
#        [[1170, 1102]],
#
#        [[1169, 1101]],
#
#        [[1169, 1098]]], dtype=int32), array([[[ 958, 1097]],
#
#        [[ 959, 1097]]], dtype=int32), array([[[ 556, 1097]]], dtype=int32), array([[[1203, 1096]],
#
#        [[1202, 1097]],
#
#        [[1200, 1097]],
#
#        [[1201, 1098]],
#
#        [[1203, 1098]],
#
#        [[1204, 1097]],
#
#        [[1205, 1097]],
#
#        [[1204, 1096]]], dtype=int32), array([[[ 878, 1095]],
#
#        [[ 878, 1097]],
#
#        [[ 879, 1098]],
#
#        [[ 880, 1098]],
#
#        [[ 880, 1097]]], dtype=int32), array([[[1359, 1094]],
#
#        [[1360, 1095]]], dtype=int32), array([[[1270, 1092]]], dtype=int32), array([[[ 875, 1092]],
#
#        [[ 875, 1093]],
#
#        [[ 876, 1093]],
#
#        [[ 876, 1092]]], dtype=int32), array([[[1528, 1091]],
#
#        [[1527, 1092]],
#
#        [[1527, 1094]],
#
#        [[1526, 1095]],
#
#        [[1526, 1096]],
#
#        [[1525, 1097]],
#
#        [[1525, 1099]],
#
#        [[1524, 1100]],
#
#        [[1524, 1101]],
#
#        [[1524, 1100]],
#
#        [[1525, 1099]],
#
#        [[1525, 1097]],
#
#        [[1526, 1096]],
#
#        [[1526, 1095]],
#
#        [[1527, 1094]],
#
#        [[1527, 1093]],
#
#        [[1528, 1092]]], dtype=int32), array([[[1355, 1090]],
#
#        [[1355, 1093]],
#
#        [[1356, 1094]],
#
#        [[1356, 1096]],
#
#        [[1356, 1092]],
#
#        [[1355, 1091]]], dtype=int32), array([[[ 273, 1089]]], dtype=int32), array([[[1457, 1087]]], dtype=int32), array([[[ 869, 1087]]], dtype=int32), array([[[ 690, 1087]],
#
#        [[ 690, 1088]],
#
#        [[ 691, 1088]]], dtype=int32), array([[[ 537, 1087]],
#
#        [[ 537, 1089]]], dtype=int32), array([[[ 848, 1086]],
#
#        [[ 846, 1088]],
#
#        [[ 847, 1088]],
#
#        [[ 849, 1086]]], dtype=int32), array([[[ 987, 1085]],
#
#        [[ 986, 1086]],
#
#        [[ 987, 1087]],
#
#        [[ 990, 1087]],
#
#        [[ 989, 1087]]], dtype=int32), array([[[1463, 1084]]], dtype=int32), array([[[1389, 1084]],
#
#        [[1386, 1087]],
#
#        [[1387, 1086]],
#
#        [[1388, 1086]],
#
#        [[1390, 1084]]], dtype=int32), array([[[ 673, 1084]]], dtype=int32), array([[[ 662, 1084]]], dtype=int32), array([[[ 655, 1084]],
#
#        [[ 655, 1085]],
#
#        [[ 660, 1085]],
#
#        [[ 660, 1084]]], dtype=int32), array([[[ 521, 1084]],
#
#        [[ 521, 1085]],
#
#        [[ 520, 1086]],
#
#        [[ 520, 1087]],
#
#        [[ 519, 1088]],
#
#        [[ 519, 1089]],
#
#        [[ 518, 1090]],
#
#        [[ 518, 1095]],
#
#        [[ 520, 1095]],
#
#        [[ 521, 1096]],
#
#        [[ 521, 1095]],
#
#        [[ 522, 1094]],
#
#        [[ 522, 1091]],
#
#        [[ 521, 1090]],
#
#        [[ 521, 1089]],
#
#        [[ 522, 1088]],
#
#        [[ 522, 1084]]], dtype=int32), array([[[ 510, 1084]]], dtype=int32), array([[[1646, 1083]],
#
#        [[1647, 1084]]], dtype=int32), array([[[1395, 1082]],
#
#        [[1394, 1083]],
#
#        [[1395, 1084]],
#
#        [[1395, 1089]],
#
#        [[1396, 1090]],
#
#        [[1396, 1095]],
#
#        [[1397, 1095]],
#
#        [[1396, 1094]],
#
#        [[1396, 1084]],
#
#        [[1395, 1083]]], dtype=int32), array([[[1319, 1081]]], dtype=int32), array([[[ 661, 1081]],
#
#        [[ 662, 1082]],
#
#        [[ 662, 1081]]], dtype=int32), array([[[ 537, 1080]]], dtype=int32), array([[[1318, 1079]]], dtype=int32), array([[[ 556, 1079]],
#
#        [[ 556, 1080]],
#
#        [[ 557, 1081]],
#
#        [[ 557, 1082]],
#
#        [[ 557, 1081]],
#
#        [[ 556, 1080]]], dtype=int32), array([[[1641, 1077]],
#
#        [[1643, 1079]],
#
#        [[1643, 1080]],
#
#        [[1644, 1081]],
#
#        [[1644, 1080]]], dtype=int32), array([[[ 964, 1076]],
#
#        [[ 964, 1077]],
#
#        [[ 965, 1077]],
#
#        [[ 966, 1076]],
#
#        [[ 967, 1077]],
#
#        [[ 968, 1076]],
#
#        [[ 969, 1077]],
#
#        [[ 972, 1077]],
#
#        [[ 973, 1078]],
#
#        [[ 976, 1078]],
#
#        [[ 977, 1079]],
#
#        [[ 978, 1079]],
#
#        [[ 979, 1080]],
#
#        [[ 979, 1081]],
#
#        [[ 981, 1083]],
#
#        [[ 981, 1082]],
#
#        [[ 980, 1081]],
#
#        [[ 980, 1080]],
#
#        [[ 981, 1079]],
#
#        [[ 983, 1079]],
#
#        [[ 984, 1080]],
#
#        [[ 985, 1080]],
#
#        [[ 986, 1081]],
#
#        [[ 990, 1081]],
#
#        [[ 991, 1082]],
#
#        [[1002, 1082]],
#
#        [[1003, 1083]],
#
#        [[1005, 1083]],
#
#        [[1006, 1082]],
#
#        [[1007, 1082]],
#
#        [[1004, 1082]],
#
#        [[1003, 1081]],
#
#        [[ 998, 1081]],
#
#        [[ 997, 1080]],
#
#        [[ 987, 1080]],
#
#        [[ 986, 1079]],
#
#        [[ 981, 1079]],
#
#        [[ 980, 1078]],
#
#        [[ 977, 1078]],
#
#        [[ 976, 1077]],
#
#        [[ 970, 1077]],
#
#        [[ 969, 1076]]], dtype=int32), array([[[ 936, 1076]],
#
#        [[ 937, 1077]],
#
#        [[ 939, 1077]],
#
#        [[ 938, 1077]],
#
#        [[ 937, 1076]]], dtype=int32), array([[[ 269, 1076]],
#
#        [[ 270, 1077]],
#
#        [[ 270, 1078]],
#
#        [[ 271, 1079]],
#
#        [[ 271, 1082]],
#
#        [[ 272, 1083]],
#
#        [[ 272, 1085]],
#
#        [[ 273, 1086]],
#
#        [[ 273, 1087]],
#
#        [[ 273, 1084]],
#
#        [[ 274, 1083]],
#
#        [[ 273, 1083]],
#
#        [[ 272, 1082]],
#
#        [[ 272, 1081]],
#
#        [[ 271, 1080]],
#
#        [[ 271, 1079]],
#
#        [[ 270, 1078]],
#
#        [[ 270, 1076]]], dtype=int32), array([[[1001, 1075]],
#
#        [[1000, 1076]],
#
#        [[ 999, 1076]],
#
#        [[ 998, 1077]],
#
#        [[1000, 1077]],
#
#        [[1000, 1076]]], dtype=int32), array([[[ 649, 1075]],
#
#        [[ 648, 1076]],
#
#        [[ 646, 1076]],
#
#        [[ 656, 1076]],
#
#        [[ 657, 1075]],
#
#        [[ 659, 1075]],
#
#        [[ 660, 1076]],
#
#        [[ 660, 1075]]], dtype=int32), array([[[1831, 1073]],
#
#        [[1831, 1074]],
#
#        [[1830, 1075]],
#
#        [[1830, 1077]],
#
#        [[1830, 1075]],
#
#        [[1831, 1074]]], dtype=int32), array([[[1459, 1073]],
#
#        [[1459, 1074]],
#
#        [[1460, 1073]],
#
#        [[1461, 1073]]], dtype=int32), array([[[ 537, 1073]],
#
#        [[ 536, 1074]],
#
#        [[ 536, 1075]],
#
#        [[ 537, 1076]],
#
#        [[ 537, 1077]],
#
#        [[ 538, 1076]],
#
#        [[ 538, 1074]]], dtype=int32), array([[[1636, 1072]],
#
#        [[1636, 1073]],
#
#        [[1638, 1075]],
#
#        [[1636, 1073]]], dtype=int32), array([[[1412, 1072]],
#
#        [[1412, 1073]],
#
#        [[1413, 1074]],
#
#        [[1414, 1074]]], dtype=int32), array([[[1176, 1072]],
#
#        [[1175, 1073]],
#
#        [[1174, 1073]],
#
#        [[1173, 1074]],
#
#        [[1171, 1074]],
#
#        [[1170, 1075]],
#
#        [[1171, 1075]],
#
#        [[1172, 1074]],
#
#        [[1176, 1074]],
#
#        [[1177, 1073]],
#
#        [[1178, 1073]],
#
#        [[1178, 1072]]], dtype=int32), array([[[ 572, 1072]],
#
#        [[ 572, 1074]],
#
#        [[ 574, 1076]],
#
#        [[ 574, 1075]],
#
#        [[ 573, 1074]],
#
#        [[ 573, 1073]]], dtype=int32), array([[[1473, 1071]]], dtype=int32), array([[[1467, 1071]]], dtype=int32), array([[[ 951, 1071]],
#
#        [[ 952, 1072]],
#
#        [[ 954, 1072]],
#
#        [[ 955, 1073]],
#
#        [[ 957, 1073]],
#
#        [[ 958, 1074]],
#
#        [[ 960, 1074]],
#
#        [[ 959, 1074]],
#
#        [[ 958, 1073]],
#
#        [[ 957, 1073]],
#
#        [[ 956, 1072]],
#
#        [[ 954, 1072]],
#
#        [[ 953, 1071]]], dtype=int32), array([[[ 467, 1071]],
#
#        [[ 467, 1072]],
#
#        [[ 471, 1076]],
#
#        [[ 470, 1075]],
#
#        [[ 470, 1074]],
#
#        [[ 469, 1073]],
#
#        [[ 468, 1073]],
#
#        [[ 467, 1072]]], dtype=int32), array([[[ 948, 1070]],
#
#        [[ 949, 1070]]], dtype=int32), array([[[ 446, 1070]],
#
#        [[ 446, 1071]],
#
#        [[ 448, 1073]],
#
#        [[ 448, 1070]]], dtype=int32), array([[[1401, 1069]],
#
#        [[1401, 1070]],
#
#        [[1400, 1071]],
#
#        [[1400, 1073]],
#
#        [[1399, 1074]],
#
#        [[1398, 1074]],
#
#        [[1398, 1077]],
#
#        [[1399, 1077]],
#
#        [[1400, 1078]],
#
#        [[1401, 1078]],
#
#        [[1401, 1077]],
#
#        [[1404, 1074]],
#
#        [[1403, 1075]],
#
#        [[1401, 1073]]], dtype=int32), array([[[1298, 1069]]], dtype=int32), array([[[1191, 1069]],
#
#        [[1192, 1070]],
#
#        [[1192, 1069]]], dtype=int32), array([[[ 999, 1069]],
#
#        [[ 998, 1070]]], dtype=int32), array([[[ 931, 1069]],
#
#        [[ 932, 1070]],
#
#        [[ 932, 1069]]], dtype=int32), array([[[1426, 1068]],
#
#        [[1426, 1069]],
#
#        [[1425, 1070]],
#
#        [[1423, 1070]],
#
#        [[1422, 1069]],
#
#        [[1422, 1070]],
#
#        [[1423, 1071]],
#
#        [[1429, 1071]],
#
#        [[1429, 1070]],
#
#        [[1427, 1068]]], dtype=int32), array([[[1350, 1068]],
#
#        [[1350, 1070]]], dtype=int32), array([[[1324, 1068]],
#
#        [[1325, 1068]]], dtype=int32), array([[[1287, 1068]],
#
#        [[1286, 1069]],
#
#        [[1291, 1069]],
#
#        [[1291, 1068]]], dtype=int32), array([[[1197, 1068]],
#
#        [[1198, 1068]]], dtype=int32), array([[[1195, 1068]],
#
#        [[1195, 1069]]], dtype=int32), array([[[ 939, 1068]],
#
#        [[ 937, 1070]],
#
#        [[ 936, 1070]],
#
#        [[ 936, 1071]],
#
#        [[ 935, 1072]],
#
#        [[ 934, 1072]],
#
#        [[ 933, 1073]],
#
#        [[ 932, 1073]],
#
#        [[ 931, 1074]],
#
#        [[ 928, 1074]],
#
#        [[ 927, 1073]],
#
#        [[ 927, 1074]],
#
#        [[ 928, 1075]],
#
#        [[ 933, 1075]],
#
#        [[ 934, 1076]],
#
#        [[ 932, 1074]],
#
#        [[ 934, 1072]],
#
#        [[ 935, 1072]],
#
#        [[ 936, 1071]],
#
#        [[ 937, 1071]],
#
#        [[ 939, 1069]]], dtype=int32), array([[[1453, 1067]],
#
#        [[1452, 1068]],
#
#        [[1445, 1068]],
#
#        [[1444, 1069]],
#
#        [[1436, 1069]],
#
#        [[1435, 1070]],
#
#        [[1433, 1070]],
#
#        [[1432, 1069]],
#
#        [[1431, 1070]],
#
#        [[1434, 1070]],
#
#        [[1435, 1071]],
#
#        [[1438, 1071]],
#
#        [[1439, 1070]],
#
#        [[1444, 1070]],
#
#        [[1445, 1069]],
#
#        [[1451, 1069]],
#
#        [[1452, 1068]],
#
#        [[1454, 1068]],
#
#        [[1454, 1067]]], dtype=int32), array([[[1416, 1067]],
#
#        [[1415, 1068]],
#
#        [[1416, 1069]],
#
#        [[1417, 1069]],
#
#        [[1416, 1068]]], dtype=int32), array([[[1295, 1067]],
#
#        [[1296, 1068]]], dtype=int32), array([[[ 967, 1067]],
#
#        [[ 968, 1067]],
#
#        [[ 969, 1068]],
#
#        [[ 970, 1068]],
#
#        [[ 971, 1069]],
#
#        [[ 973, 1069]],
#
#        [[ 975, 1071]],
#
#        [[ 975, 1070]],
#
#        [[ 974, 1070]],
#
#        [[ 973, 1069]],
#
#        [[ 972, 1069]],
#
#        [[ 971, 1068]],
#
#        [[ 970, 1068]],
#
#        [[ 969, 1067]]], dtype=int32), array([[[1099, 1065]],
#
#        [[1098, 1066]],
#
#        [[1098, 1067]],
#
#        [[1099, 1067]]], dtype=int32), array([[[ 867, 1065]],
#
#        [[ 865, 1067]],
#
#        [[ 865, 1068]],
#
#        [[ 868, 1065]]], dtype=int32), array([[[ 551, 1065]]], dtype=int32), array([[[1348, 1064]],
#
#        [[1349, 1065]],
#
#        [[1349, 1066]],
#
#        [[1349, 1065]]], dtype=int32), array([[[1245, 1064]],
#
#        [[1244, 1065]],
#
#        [[1245, 1065]]], dtype=int32), array([[[1093, 1064]],
#
#        [[1093, 1066]]], dtype=int32), array([[[1073, 1064]],
#
#        [[1074, 1065]],
#
#        [[1075, 1065]],
#
#        [[1074, 1065]]], dtype=int32), array([[[1006, 1064]],
#
#        [[1005, 1065]],
#
#        [[1004, 1065]],
#
#        [[1005, 1065]]], dtype=int32), array([[[ 445, 1064]],
#
#        [[ 444, 1065]],
#
#        [[ 443, 1065]],
#
#        [[ 445, 1067]],
#
#        [[ 445, 1068]],
#
#        [[ 446, 1068]],
#
#        [[ 446, 1065]]], dtype=int32), array([[[1625, 1063]],
#
#        [[1626, 1064]]], dtype=int32), array([[[1430, 1063]],
#
#        [[1430, 1064]],
#
#        [[1431, 1065]],
#
#        [[1432, 1065]]], dtype=int32), array([[[ 550, 1062]],
#
#        [[ 550, 1063]]], dtype=int32), array([[[ 484, 1062]],
#
#        [[ 484, 1063]],
#
#        [[ 485, 1063]],
#
#        [[ 486, 1064]],
#
#        [[ 488, 1064]],
#
#        [[ 488, 1063]],
#
#        [[ 487, 1064]],
#
#        [[ 486, 1063]],
#
#        [[ 486, 1062]]], dtype=int32), array([[[1073, 1061]]], dtype=int32), array([[[ 953, 1061]],
#
#        [[ 954, 1062]],
#
#        [[ 955, 1062]],
#
#        [[ 956, 1063]],
#
#        [[ 958, 1063]],
#
#        [[ 959, 1064]],
#
#        [[ 960, 1064]],
#
#        [[ 961, 1065]],
#
#        [[ 963, 1065]],
#
#        [[ 964, 1066]],
#
#        [[ 965, 1065]],
#
#        [[ 964, 1065]],
#
#        [[ 963, 1064]],
#
#        [[ 962, 1064]],
#
#        [[ 961, 1063]],
#
#        [[ 959, 1063]],
#
#        [[ 958, 1062]],
#
#        [[ 956, 1062]],
#
#        [[ 955, 1061]]], dtype=int32), array([[[1404, 1060]],
#
#        [[1404, 1062]],
#
#        [[1406, 1064]],
#
#        [[1406, 1065]],
#
#        [[1409, 1068]],
#
#        [[1409, 1067]],
#
#        [[1408, 1066]],
#
#        [[1408, 1065]],
#
#        [[1407, 1064]],
#
#        [[1407, 1063]]], dtype=int32), array([[[1350, 1060]]], dtype=int32), array([[[1269, 1060]],
#
#        [[1270, 1061]],
#
#        [[1270, 1060]]], dtype=int32), array([[[1422, 1059]]], dtype=int32), array([[[1371, 1059]]], dtype=int32), array([[[1644, 1058]]], dtype=int32), array([[[1362, 1058]]], dtype=int32), array([[[1201, 1058]],
#
#        [[1200, 1059]],
#
#        [[1199, 1059]],
#
#        [[1201, 1059]]], dtype=int32), array([[[1222, 1057]],
#
#        [[1222, 1058]],
#
#        [[1223, 1057]]], dtype=int32), array([[[ 563, 1057]],
#
#        [[ 562, 1058]],
#
#        [[ 566, 1062]],
#
#        [[ 566, 1063]],
#
#        [[ 567, 1064]],
#
#        [[ 567, 1065]],
#
#        [[ 568, 1066]],
#
#        [[ 569, 1066]],
#
#        [[ 566, 1063]],
#
#        [[ 566, 1061]],
#
#        [[ 565, 1060]],
#
#        [[ 565, 1058]],
#
#        [[ 564, 1058]]], dtype=int32), array([[[1259, 1056]],
#
#        [[1258, 1057]],
#
#        [[1257, 1057]],
#
#        [[1257, 1059]],
#
#        [[1258, 1060]],
#
#        [[1259, 1060]],
#
#        [[1258, 1059]],
#
#        [[1258, 1058]],
#
#        [[1259, 1057]]], dtype=int32), array([[[1216, 1056]],
#
#        [[1216, 1059]],
#
#        [[1217, 1058]],
#
#        [[1217, 1057]],
#
#        [[1218, 1056]]], dtype=int32), array([[[1089, 1056]],
#
#        [[1089, 1057]],
#
#        [[1090, 1058]],
#
#        [[1090, 1059]],
#
#        [[1091, 1060]],
#
#        [[1091, 1061]],
#
#        [[1092, 1061]],
#
#        [[1092, 1060]],
#
#        [[1091, 1059]],
#
#        [[1091, 1058]]], dtype=int32), array([[[1017, 1056]],
#
#        [[1016, 1057]],
#
#        [[1017, 1057]],
#
#        [[1018, 1056]]], dtype=int32), array([[[1618, 1055]],
#
#        [[1619, 1056]],
#
#        [[1619, 1057]],
#
#        [[1621, 1059]],
#
#        [[1621, 1060]],
#
#        [[1622, 1060]],
#
#        [[1622, 1059]],
#
#        [[1621, 1059]],
#
#        [[1619, 1057]],
#
#        [[1619, 1056]]], dtype=int32), array([[[1270, 1055]],
#
#        [[1271, 1055]]], dtype=int32), array([[[ 487, 1055]],
#
#        [[ 486, 1056]],
#
#        [[ 485, 1056]],
#
#        [[ 484, 1057]],
#
#        [[ 485, 1057]],
#
#        [[ 486, 1058]],
#
#        [[ 484, 1060]],
#
#        [[ 482, 1060]],
#
#        [[ 486, 1060]],
#
#        [[ 487, 1059]],
#
#        [[ 489, 1059]],
#
#        [[ 490, 1060]],
#
#        [[ 491, 1059]],
#
#        [[ 492, 1059]],
#
#        [[ 493, 1060]],
#
#        [[ 493, 1061]],
#
#        [[ 492, 1062]],
#
#        [[ 492, 1064]],
#
#        [[ 491, 1065]],
#
#        [[ 493, 1065]],
#
#        [[ 495, 1063]],
#
#        [[ 497, 1063]],
#
#        [[ 499, 1065]],
#
#        [[ 498, 1066]],
#
#        [[ 498, 1067]],
#
#        [[ 499, 1067]],
#
#        [[ 500, 1066]],
#
#        [[ 502, 1066]],
#
#        [[ 502, 1063]],
#
#        [[ 501, 1062]],
#
#        [[ 499, 1062]],
#
#        [[ 498, 1061]],
#
#        [[ 497, 1061]],
#
#        [[ 496, 1060]],
#
#        [[ 496, 1059]],
#
#        [[ 497, 1058]],
#
#        [[ 500, 1058]],
#
#        [[ 497, 1058]],
#
#        [[ 496, 1057]],
#
#        [[ 495, 1057]],
#
#        [[ 494, 1056]],
#
#        [[ 493, 1056]],
#
#        [[ 492, 1055]],
#
#        [[ 493, 1056]],
#
#        [[ 492, 1057]],
#
#        [[ 491, 1057]],
#
#        [[ 490, 1056]],
#
#        [[ 489, 1056]],
#
#        [[ 488, 1055]]], dtype=int32), array([[[1263, 1054]]], dtype=int32), array([[[ 439, 1054]],
#
#        [[ 439, 1056]],
#
#        [[ 441, 1058]],
#
#        [[ 442, 1058]],
#
#        [[ 442, 1054]]], dtype=int32), array([[[1472, 1053]],
#
#        [[1469, 1056]],
#
#        [[1469, 1057]],
#
#        [[1467, 1059]],
#
#        [[1467, 1060]],
#
#        [[1466, 1061]],
#
#        [[1466, 1062]],
#
#        [[1465, 1063]],
#
#        [[1465, 1064]],
#
#        [[1463, 1066]],
#
#        [[1463, 1067]],
#
#        [[1462, 1068]],
#
#        [[1462, 1069]],
#
#        [[1463, 1068]],
#
#        [[1463, 1067]],
#
#        [[1465, 1065]],
#
#        [[1465, 1064]],
#
#        [[1466, 1063]],
#
#        [[1466, 1062]],
#
#        [[1468, 1060]],
#
#        [[1468, 1059]],
#
#        [[1469, 1058]],
#
#        [[1469, 1057]],
#
#        [[1470, 1056]],
#
#        [[1470, 1055]]], dtype=int32), array([[[1366, 1053]]], dtype=int32), array([[[1253, 1053]],
#
#        [[1252, 1054]],
#
#        [[1251, 1054]],
#
#        [[1250, 1055]],
#
#        [[1251, 1056]],
#
#        [[1252, 1056]],
#
#        [[1252, 1055]],
#
#        [[1253, 1054]],
#
#        [[1254, 1054]],
#
#        [[1255, 1053]]], dtype=int32), array([[[1217, 1053]],
#
#        [[1218, 1054]],
#
#        [[1219, 1054]],
#
#        [[1218, 1053]]], dtype=int32), array([[[1054, 1053]],
#
#        [[1052, 1055]],
#
#        [[1053, 1054]],
#
#        [[1054, 1054]]], dtype=int32), array([[[1227, 1052]],
#
#        [[1227, 1053]],
#
#        [[1228, 1053]],
#
#        [[1228, 1052]]], dtype=int32), array([[[1223, 1052]],
#
#        [[1222, 1053]],
#
#        [[1223, 1053]],
#
#        [[1224, 1052]],
#
#        [[1225, 1053]],
#
#        [[1224, 1052]]], dtype=int32), array([[[ 669, 1052]]], dtype=int32), array([[[1617, 1051]]], dtype=int32), array([[[1489, 1051]]], dtype=int32), array([[[1465, 1051]],
#
#        [[1465, 1052]],
#
#        [[1466, 1052]]], dtype=int32), array([[[1438, 1051]],
#
#        [[1437, 1052]],
#
#        [[1437, 1053]],
#
#        [[1436, 1054]],
#
#        [[1438, 1052]]], dtype=int32), array([[[1363, 1051]]], dtype=int32), array([[[1230, 1051]],
#
#        [[1230, 1052]],
#
#        [[1231, 1051]]], dtype=int32), array([[[1310, 1050]],
#
#        [[1311, 1050]]], dtype=int32), array([[[1061, 1050]],
#
#        [[1063, 1050]]], dtype=int32), array([[[ 697, 1050]],
#
#        [[ 696, 1051]],
#
#        [[ 697, 1050]],
#
#        [[ 698, 1050]]], dtype=int32), array([[[ 549, 1050]],
#
#        [[ 550, 1050]]], dtype=int32), array([[[ 468, 1050]]], dtype=int32), array([[[ 457, 1050]],
#
#        [[ 456, 1051]],
#
#        [[ 455, 1051]],
#
#        [[ 454, 1052]],
#
#        [[ 452, 1052]],
#
#        [[ 454, 1052]],
#
#        [[ 455, 1053]],
#
#        [[ 455, 1054]],
#
#        [[ 460, 1054]],
#
#        [[ 461, 1053]],
#
#        [[ 463, 1053]],
#
#        [[ 463, 1052]],
#
#        [[ 464, 1051]],
#
#        [[ 461, 1051]],
#
#        [[ 460, 1050]]], dtype=int32), array([[[1440, 1049]]], dtype=int32), array([[[1266, 1049]]], dtype=int32), array([[[1226, 1049]]], dtype=int32), array([[[1189, 1049]],
#
#        [[1190, 1050]],
#
#        [[1190, 1049]]], dtype=int32), array([[[ 791, 1049]],
#
#        [[ 791, 1050]],
#
#        [[ 792, 1050]]], dtype=int32), array([[[ 437, 1049]],
#
#        [[ 437, 1050]],
#
#        [[ 439, 1050]],
#
#        [[ 439, 1049]]], dtype=int32), array([[[1465, 1048]]], dtype=int32), array([[[1417, 1048]],
#
#        [[1417, 1049]],
#
#        [[1416, 1050]],
#
#        [[1416, 1052]],
#
#        [[1419, 1055]],
#
#        [[1420, 1055]],
#
#        [[1419, 1054]],
#
#        [[1419, 1052]],
#
#        [[1418, 1051]],
#
#        [[1418, 1050]],
#
#        [[1417, 1049]]], dtype=int32), array([[[1284, 1048]],
#
#        [[1283, 1049]],
#
#        [[1282, 1049]],
#
#        [[1282, 1050]],
#
#        [[1281, 1051]],
#
#        [[1280, 1051]],
#
#        [[1279, 1052]],
#
#        [[1281, 1052]],
#
#        [[1282, 1051]],
#
#        [[1282, 1050]]], dtype=int32), array([[[ 760, 1047]],
#
#        [[ 761, 1048]],
#
#        [[ 761, 1047]]], dtype=int32), array([[[ 597, 1047]],
#
#        [[ 596, 1048]],
#
#        [[ 595, 1048]],
#
#        [[ 594, 1049]],
#
#        [[ 593, 1049]],
#
#        [[ 592, 1050]],
#
#        [[ 590, 1050]],
#
#        [[ 588, 1052]],
#
#        [[ 586, 1052]],
#
#        [[ 585, 1053]],
#
#        [[ 584, 1053]],
#
#        [[ 583, 1054]],
#
#        [[ 582, 1054]],
#
#        [[ 581, 1055]],
#
#        [[ 579, 1055]],
#
#        [[ 578, 1056]],
#
#        [[ 577, 1056]],
#
#        [[ 575, 1058]],
#
#        [[ 574, 1058]],
#
#        [[ 580, 1058]],
#
#        [[ 582, 1056]],
#
#        [[ 583, 1056]],
#
#        [[ 585, 1054]],
#
#        [[ 587, 1054]],
#
#        [[ 589, 1052]],
#
#        [[ 590, 1052]],
#
#        [[ 591, 1051]],
#
#        [[ 592, 1051]],
#
#        [[ 593, 1050]],
#
#        [[ 596, 1050]],
#
#        [[ 598, 1048]]], dtype=int32), array([[[ 481, 1047]],
#
#        [[ 480, 1048]],
#
#        [[ 481, 1049]]], dtype=int32), array([[[1644, 1046]],
#
#        [[1644, 1055]]], dtype=int32), array([[[1316, 1046]],
#
#        [[1318, 1048]]], dtype=int32), array([[[1260, 1046]]], dtype=int32), array([[[ 428, 1046]],
#
#        [[ 428, 1047]],
#
#        [[ 429, 1046]]], dtype=int32), array([[[1513, 1045]]], dtype=int32), array([[[1296, 1045]],
#
#        [[1294, 1047]],
#
#        [[1293, 1047]],
#
#        [[1291, 1049]],
#
#        [[1292, 1048]],
#
#        [[1293, 1048]],
#
#        [[1295, 1046]],
#
#        [[1296, 1046]]], dtype=int32), array([[[1286, 1045]],
#
#        [[1285, 1046]],
#
#        [[1286, 1046]]], dtype=int32), array([[[ 790, 1045]],
#
#        [[ 790, 1046]],
#
#        [[ 793, 1046]],
#
#        [[ 793, 1045]]], dtype=int32), array([[[1263, 1044]]], dtype=int32), array([[[1205, 1044]]], dtype=int32), array([[[1201, 1044]],
#
#        [[1200, 1045]],
#
#        [[1200, 1046]],
#
#        [[1198, 1048]],
#
#        [[1198, 1049]],
#
#        [[1197, 1050]],
#
#        [[1197, 1051]],
#
#        [[1196, 1052]],
#
#        [[1196, 1055]],
#
#        [[1194, 1057]],
#
#        [[1194, 1060]],
#
#        [[1192, 1062]],
#
#        [[1192, 1064]],
#
#        [[1191, 1065]],
#
#        [[1191, 1067]],
#
#        [[1192, 1067]],
#
#        [[1192, 1065]],
#
#        [[1193, 1064]],
#
#        [[1193, 1062]],
#
#        [[1194, 1061]],
#
#        [[1194, 1060]],
#
#        [[1195, 1059]],
#
#        [[1195, 1058]],
#
#        [[1196, 1057]],
#
#        [[1196, 1056]],
#
#        [[1197, 1055]],
#
#        [[1197, 1053]],
#
#        [[1198, 1052]],
#
#        [[1198, 1051]],
#
#        [[1199, 1050]],
#
#        [[1199, 1049]],
#
#        [[1201, 1047]]], dtype=int32), array([[[1186, 1044]]], dtype=int32), array([[[1038, 1044]],
#
#        [[1039, 1044]]], dtype=int32), array([[[1025, 1044]],
#
#        [[1024, 1045]],
#
#        [[1024, 1046]],
#
#        [[1024, 1045]]], dtype=int32), array([[[ 646, 1044]]], dtype=int32), array([[[1444, 1043]],
#
#        [[1443, 1044]],
#
#        [[1443, 1045]],
#
#        [[1444, 1044]]], dtype=int32), array([[[1184, 1043]],
#
#        [[1183, 1044]],
#
#        [[1183, 1045]],
#
#        [[1184, 1046]]], dtype=int32), array([[[1049, 1043]],
#
#        [[1048, 1044]],
#
#        [[1047, 1044]],
#
#        [[1050, 1044]],
#
#        [[1051, 1045]],
#
#        [[1051, 1043]]], dtype=int32), array([[[1029, 1043]]], dtype=int32), array([[[ 983, 1043]],
#
#        [[ 984, 1043]]], dtype=int32), array([[[ 539, 1043]],
#
#        [[ 538, 1044]],
#
#        [[ 539, 1045]],
#
#        [[ 539, 1046]],
#
#        [[ 542, 1046]],
#
#        [[ 541, 1046]],
#
#        [[ 540, 1045]],
#
#        [[ 540, 1044]],
#
#        [[ 541, 1043]]], dtype=int32), array([[[ 430, 1043]],
#
#        [[ 430, 1044]]], dtype=int32), array([[[1490, 1042]],
#
#        [[1491, 1042]]], dtype=int32), array([[[1483, 1042]],
#
#        [[1480, 1045]],
#
#        [[1479, 1045]],
#
#        [[1477, 1047]],
#
#        [[1478, 1047]],
#
#        [[1479, 1046]],
#
#        [[1480, 1046]],
#
#        [[1484, 1042]]], dtype=int32), array([[[1268, 1042]]], dtype=int32), array([[[1206, 1042]]], dtype=int32), array([[[ 796, 1042]],
#
#        [[ 797, 1042]],
#
#        [[ 798, 1043]],
#
#        [[ 800, 1043]],
#
#        [[ 801, 1044]],
#
#        [[ 800, 1045]],
#
#        [[ 797, 1045]],
#
#        [[ 798, 1046]],
#
#        [[ 800, 1046]],
#
#        [[ 801, 1045]],
#
#        [[ 807, 1045]],
#
#        [[ 808, 1044]],
#
#        [[ 810, 1044]],
#
#        [[ 811, 1045]],
#
#        [[ 812, 1045]],
#
#        [[ 813, 1044]],
#
#        [[ 818, 1044]],
#
#        [[ 819, 1043]],
#
#        [[ 823, 1043]],
#
#        [[ 822, 1042]],
#
#        [[ 821, 1043]],
#
#        [[ 820, 1042]],
#
#        [[ 819, 1042]],
#
#        [[ 818, 1043]],
#
#        [[ 814, 1043]],
#
#        [[ 813, 1044]],
#
#        [[ 806, 1044]],
#
#        [[ 805, 1043]],
#
#        [[ 802, 1043]],
#
#        [[ 801, 1042]]], dtype=int32), array([[[1445, 1041]]], dtype=int32), array([[[1311, 1041]],
#
#        [[1309, 1043]],
#
#        [[1308, 1042]],
#
#        [[1307, 1042]],
#
#        [[1307, 1043]],
#
#        [[1309, 1043]],
#
#        [[1310, 1042]],
#
#        [[1312, 1042]]], dtype=int32), array([[[1254, 1041]]], dtype=int32), array([[[1199, 1041]]], dtype=int32), array([[[ 833, 1041]]], dtype=int32), array([[[ 791, 1041]],
#
#        [[ 792, 1041]]], dtype=int32), array([[[1644, 1040]],
#
#        [[1644, 1043]]], dtype=int32), array([[[ 981, 1040]],
#
#        [[ 980, 1041]],
#
#        [[ 978, 1041]],
#
#        [[ 981, 1041]]], dtype=int32), array([[[ 689, 1040]]], dtype=int32), array([[[1558, 1039]],
#
#        [[1558, 1040]]], dtype=int32), array([[[1529, 1039]],
#
#        [[1528, 1040]],
#
#        [[1526, 1040]],
#
#        [[1525, 1041]],
#
#        [[1523, 1041]],
#
#        [[1522, 1042]],
#
#        [[1519, 1042]],
#
#        [[1518, 1043]],
#
#        [[1517, 1043]],
#
#        [[1516, 1044]],
#
#        [[1515, 1044]],
#
#        [[1515, 1045]],
#
#        [[1516, 1045]],
#
#        [[1517, 1044]],
#
#        [[1520, 1044]],
#
#        [[1521, 1043]],
#
#        [[1522, 1043]],
#
#        [[1523, 1042]],
#
#        [[1525, 1042]],
#
#        [[1526, 1041]],
#
#        [[1527, 1041]],
#
#        [[1528, 1040]],
#
#        [[1529, 1040]],
#
#        [[1530, 1039]]], dtype=int32), array([[[1487, 1039]],
#
#        [[1487, 1040]],
#
#        [[1488, 1040]],
#
#        [[1488, 1039]]], dtype=int32), array([[[1235, 1039]],
#
#        [[1236, 1040]],
#
#        [[1239, 1040]],
#
#        [[1238, 1039]]], dtype=int32), array([[[1221, 1039]],
#
#        [[1221, 1040]]], dtype=int32), array([[[1190, 1039]],
#
#        [[1188, 1041]],
#
#        [[1188, 1042]],
#
#        [[1191, 1039]]], dtype=int32), array([[[1446, 1038]]], dtype=int32), array([[[1325, 1038]],
#
#        [[1325, 1039]],
#
#        [[1326, 1040]],
#
#        [[1326, 1038]]], dtype=int32), array([[[1315, 1038]],
#
#        [[1314, 1039]],
#
#        [[1314, 1041]],
#
#        [[1315, 1041]],
#
#        [[1317, 1039]],
#
#        [[1317, 1038]]], dtype=int32), array([[[1231, 1038]],
#
#        [[1232, 1039]],
#
#        [[1233, 1039]],
#
#        [[1232, 1038]]], dtype=int32), array([[[1049, 1038]],
#
#        [[1050, 1039]],
#
#        [[1051, 1039]],
#
#        [[1050, 1038]]], dtype=int32), array([[[1044, 1038]]], dtype=int32), array([[[ 677, 1038]],
#
#        [[ 676, 1039]],
#
#        [[ 675, 1039]],
#
#        [[ 677, 1039]]], dtype=int32), array([[[1566, 1037]],
#
#        [[1565, 1038]],
#
#        [[1564, 1038]],
#
#        [[1566, 1038]],
#
#        [[1567, 1037]]], dtype=int32), array([[[1135, 1037]],
#
#        [[1134, 1038]],
#
#        [[1132, 1038]],
#
#        [[1136, 1038]],
#
#        [[1136, 1037]]], dtype=int32), array([[[ 720, 1037]],
#
#        [[ 719, 1038]],
#
#        [[ 712, 1038]],
#
#        [[ 719, 1038]],
#
#        [[ 720, 1037]],
#
#        [[ 722, 1037]]], dtype=int32), array([[[ 700, 1037]],
#
#        [[ 700, 1038]],
#
#        [[ 701, 1038]],
#
#        [[ 701, 1037]]], dtype=int32), array([[[1032, 1036]],
#
#        [[1033, 1037]],
#
#        [[1036, 1037]],
#
#        [[1037, 1038]],
#
#        [[1037, 1039]],
#
#        [[1036, 1040]],
#
#        [[1038, 1038]],
#
#        [[1039, 1039]],
#
#        [[1041, 1037]],
#
#        [[1038, 1037]],
#
#        [[1037, 1036]],
#
#        [[1036, 1036]],
#
#        [[1035, 1037]],
#
#        [[1034, 1036]]], dtype=int32), array([[[1693, 1035]],
#
#        [[1693, 1038]],
#
#        [[1694, 1039]],
#
#        [[1694, 1042]],
#
#        [[1695, 1042]],
#
#        [[1694, 1041]],
#
#        [[1694, 1037]],
#
#        [[1693, 1036]]], dtype=int32), array([[[1570, 1035]],
#
#        [[1569, 1036]]], dtype=int32), array([[[1357, 1035]],
#
#        [[1358, 1035]]], dtype=int32), array([[[1150, 1035]],
#
#        [[1149, 1036]],
#
#        [[1144, 1036]],
#
#        [[1145, 1036]],
#
#        [[1147, 1038]],
#
#        [[1148, 1037]],
#
#        [[1154, 1037]],
#
#        [[1153, 1037]],
#
#        [[1151, 1035]]], dtype=int32), array([[[ 804, 1035]],
#
#        [[ 805, 1036]],
#
#        [[ 805, 1035]]], dtype=int32), array([[[1214, 1034]],
#
#        [[1213, 1035]],
#
#        [[1213, 1037]],
#
#        [[1213, 1036]],
#
#        [[1215, 1034]]], dtype=int32), array([[[1046, 1034]],
#
#        [[1046, 1035]],
#
#        [[1047, 1036]],
#
#        [[1047, 1037]],
#
#        [[1048, 1036]],
#
#        [[1047, 1036]],
#
#        [[1046, 1035]],
#
#        [[1047, 1034]]], dtype=int32), array([[[ 672, 1034]],
#
#        [[ 673, 1034]]], dtype=int32), array([[[ 608, 1034]]], dtype=int32), array([[[ 469, 1034]],
#
#        [[ 472, 1034]]], dtype=int32), array([[[1644, 1033]]], dtype=int32), array([[[1640, 1033]],
#
#        [[1640, 1034]],
#
#        [[1641, 1035]],
#
#        [[1641, 1034]]], dtype=int32), array([[[1508, 1033]],
#
#        [[1508, 1034]]], dtype=int32), array([[[1368, 1033]]], dtype=int32), array([[[ 692, 1033]],
#
#        [[ 692, 1034]],
#
#        [[ 693, 1034]],
#
#        [[ 693, 1033]]], dtype=int32), array([[[ 677, 1033]],
#
#        [[ 677, 1034]],
#
#        [[ 678, 1035]],
#
#        [[ 679, 1035]],
#
#        [[ 678, 1034]],
#
#        [[ 678, 1033]]], dtype=int32), array([[[1502, 1032]],
#
#        [[1501, 1033]],
#
#        [[1499, 1033]],
#
#        [[1499, 1034]],
#
#        [[1500, 1035]],
#
#        [[1500, 1036]],
#
#        [[1499, 1037]],
#
#        [[1499, 1038]],
#
#        [[1500, 1038]],
#
#        [[1501, 1037]],
#
#        [[1501, 1036]],
#
#        [[1500, 1035]],
#
#        [[1501, 1034]],
#
#        [[1501, 1033]]], dtype=int32), array([[[1329, 1032]],
#
#        [[1329, 1033]]], dtype=int32), array([[[1304, 1032]],
#
#        [[1304, 1033]]], dtype=int32), array([[[1205, 1032]],
#
#        [[1205, 1033]],
#
#        [[1206, 1033]],
#
#        [[1207, 1032]]], dtype=int32), array([[[1372, 1031]],
#
#        [[1373, 1031]]], dtype=int32), array([[[1192, 1031]],
#
#        [[1191, 1032]]], dtype=int32), array([[[1376, 1030]]], dtype=int32), array([[[1209, 1030]]], dtype=int32), array([[[1578, 1029]],
#
#        [[1576, 1031]],
#
#        [[1575, 1031]],
#
#        [[1572, 1034]],
#
#        [[1573, 1033]],
#
#        [[1574, 1033]],
#
#        [[1575, 1032]],
#
#        [[1576, 1032]],
#
#        [[1577, 1031]],
#
#        [[1578, 1031]],
#
#        [[1579, 1030]],
#
#        [[1579, 1029]]], dtype=int32), array([[[1452, 1029]]], dtype=int32), array([[[1463, 1028]],
#
#        [[1463, 1029]],
#
#        [[1464, 1029]],
#
#        [[1464, 1028]]], dtype=int32), array([[[1461, 1028]]], dtype=int32), array([[[1408, 1028]],
#
#        [[1407, 1029]],
#
#        [[1407, 1030]],
#
#        [[1405, 1032]],
#
#        [[1405, 1034]],
#
#        [[1404, 1035]],
#
#        [[1404, 1036]],
#
#        [[1402, 1038]],
#
#        [[1402, 1040]],
#
#        [[1401, 1041]],
#
#        [[1401, 1042]],
#
#        [[1400, 1043]],
#
#        [[1400, 1044]],
#
#        [[1398, 1046]],
#
#        [[1398, 1047]],
#
#        [[1396, 1049]],
#
#        [[1396, 1051]],
#
#        [[1395, 1052]],
#
#        [[1395, 1054]],
#
#        [[1394, 1055]],
#
#        [[1394, 1056]],
#
#        [[1393, 1057]],
#
#        [[1393, 1058]],
#
#        [[1392, 1059]],
#
#        [[1392, 1060]],
#
#        [[1394, 1058]],
#
#        [[1394, 1057]],
#
#        [[1395, 1056]],
#
#        [[1395, 1055]],
#
#        [[1396, 1054]],
#
#        [[1396, 1053]],
#
#        [[1397, 1052]],
#
#        [[1397, 1051]],
#
#        [[1398, 1050]],
#
#        [[1398, 1048]],
#
#        [[1399, 1047]],
#
#        [[1399, 1046]],
#
#        [[1400, 1045]],
#
#        [[1400, 1044]],
#
#        [[1401, 1043]],
#
#        [[1401, 1042]],
#
#        [[1402, 1041]],
#
#        [[1402, 1040]],
#
#        [[1403, 1039]],
#
#        [[1403, 1038]],
#
#        [[1404, 1037]],
#
#        [[1404, 1036]],
#
#        [[1405, 1035]],
#
#        [[1405, 1033]],
#
#        [[1406, 1032]],
#
#        [[1406, 1031]],
#
#        [[1407, 1030]],
#
#        [[1407, 1029]]], dtype=int32), array([[[ 543, 1028]],
#
#        [[ 543, 1029]],
#
#        [[ 544, 1028]]], dtype=int32), array([[[1577, 1026]],
#
#        [[1578, 1026]]], dtype=int32), array([[[1501, 1026]],
#
#        [[1501, 1028]],
#
#        [[1500, 1029]],
#
#        [[1502, 1027]],
#
#        [[1502, 1026]]], dtype=int32), array([[[1409, 1026]]], dtype=int32), array([[[ 502, 1026]]], dtype=int32), array([[[1601, 1025]],
#
#        [[1601, 1026]],
#
#        [[1602, 1025]]], dtype=int32), array([[[1527, 1025]],
#
#        [[1527, 1026]]], dtype=int32), array([[[1349, 1025]],
#
#        [[1349, 1026]],
#
#        [[1350, 1026]],
#
#        [[1350, 1025]]], dtype=int32), array([[[1345, 1025]],
#
#        [[1345, 1026]],
#
#        [[1346, 1027]],
#
#        [[1346, 1025]]], dtype=int32), array([[[1241, 1025]],
#
#        [[1241, 1026]],
#
#        [[1242, 1026]],
#
#        [[1242, 1025]]], dtype=int32), array([[[1606, 1024]],
#
#        [[1605, 1025]],
#
#        [[1604, 1025]],
#
#        [[1606, 1025]]], dtype=int32), array([[[1533, 1024]],
#
#        [[1533, 1025]],
#
#        [[1536, 1025]],
#
#        [[1537, 1024]],
#
#        [[1536, 1025]],
#
#        [[1535, 1025]],
#
#        [[1534, 1024]]], dtype=int32), array([[[1507, 1024]],
#
#        [[1507, 1027]],
#
#        [[1508, 1026]],
#
#        [[1508, 1025]]], dtype=int32), array([[[1310, 1024]]], dtype=int32), array([[[1872, 1023]],
#
#        [[1870, 1025]],
#
#        [[1870, 1026]],
#
#        [[1869, 1027]],
#
#        [[1870, 1027]],
#
#        [[1870, 1026]],
#
#        [[1871, 1025]],
#
#        [[1871, 1024]]], dtype=int32), array([[[1587, 1023]]], dtype=int32), array([[[1553, 1023]]], dtype=int32), array([[[1354, 1023]]], dtype=int32), array([[[1297, 1023]],
#
#        [[1298, 1023]]], dtype=int32), array([[[1294, 1023]],
#
#        [[1294, 1025]]], dtype=int32), array([[[1076, 1023]],
#
#        [[1072, 1027]],
#
#        [[1071, 1027]],
#
#        [[1069, 1029]],
#
#        [[1069, 1030]],
#
#        [[1071, 1028]],
#
#        [[1072, 1028]],
#
#        [[1072, 1027]],
#
#        [[1074, 1025]],
#
#        [[1075, 1025]],
#
#        [[1076, 1024]]], dtype=int32), array([[[ 701, 1023]]], dtype=int32), array([[[1571, 1022]],
#
#        [[1570, 1023]],
#
#        [[1570, 1024]],
#
#        [[1571, 1024]],
#
#        [[1571, 1023]],
#
#        [[1572, 1022]]], dtype=int32), array([[[1547, 1022]],
#
#        [[1548, 1023]]], dtype=int32), array([[[1338, 1022]],
#
#        [[1338, 1023]],
#
#        [[1339, 1023]],
#
#        [[1339, 1022]]], dtype=int32), array([[[1329, 1022]]], dtype=int32), array([[[1163, 1022]]], dtype=int32), array([[[1873, 1021]]], dtype=int32), array([[[1593, 1021]]], dtype=int32), array([[[1542, 1021]],
#
#        [[1542, 1022]],
#
#        [[1543, 1022]],
#
#        [[1545, 1024]],
#
#        [[1545, 1025]],
#
#        [[1545, 1023]],
#
#        [[1544, 1023]]], dtype=int32), array([[[1397, 1021]],
#
#        [[1397, 1022]],
#
#        [[1398, 1022]],
#
#        [[1398, 1021]]], dtype=int32), array([[[ 791, 1021]],
#
#        [[ 792, 1022]],
#
#        [[ 792, 1021]]], dtype=int32), array([[[1522, 1020]],
#
#        [[1521, 1021]],
#
#        [[1521, 1022]],
#
#        [[1522, 1021]]], dtype=int32), array([[[1078, 1020]],
#
#        [[1078, 1022]],
#
#        [[1079, 1022]],
#
#        [[1080, 1021]],
#
#        [[1080, 1020]]], dtype=int32), array([[[ 704, 1020]],
#
#        [[ 704, 1021]],
#
#        [[ 705, 1021]],
#
#        [[ 705, 1020]]], dtype=int32), array([[[ 200, 1020]]], dtype=int32), array([[[1527, 1019]],
#
#        [[1527, 1021]],
#
#        [[1528, 1021]],
#
#        [[1527, 1020]]], dtype=int32), array([[[1259, 1019]]], dtype=int32), array([[[1088, 1019]],
#
#        [[1087, 1020]],
#
#        [[1087, 1030]],
#
#        [[1086, 1031]],
#
#        [[1086, 1034]],
#
#        [[1085, 1035]],
#
#        [[1085, 1037]],
#
#        [[1084, 1038]],
#
#        [[1085, 1038]],
#
#        [[1085, 1037]],
#
#        [[1086, 1036]],
#
#        [[1086, 1033]],
#
#        [[1087, 1032]],
#
#        [[1087, 1030]],
#
#        [[1088, 1029]],
#
#        [[1088, 1027]],
#
#        [[1089, 1026]],
#
#        [[1088, 1025]],
#
#        [[1088, 1023]],
#
#        [[1089, 1022]],
#
#        [[1089, 1020]]], dtype=int32), array([[[1556, 1018]],
#
#        [[1555, 1019]],
#
#        [[1554, 1019]],
#
#        [[1555, 1019]]], dtype=int32), array([[[1322, 1018]]], dtype=int32), array([[[ 770, 1018]],
#
#        [[ 772, 1018]],
#
#        [[ 773, 1019]],
#
#        [[ 775, 1019]],
#
#        [[ 773, 1019]],
#
#        [[ 772, 1018]]], dtype=int32), array([[[1613, 1017]],
#
#        [[1614, 1018]]], dtype=int32), array([[[1597, 1017]],
#
#        [[1598, 1018]],
#
#        [[1598, 1019]],
#
#        [[1597, 1020]],
#
#        [[1596, 1020]],
#
#        [[1595, 1019]],
#
#        [[1596, 1020]],
#
#        [[1596, 1022]],
#
#        [[1599, 1019]],
#
#        [[1599, 1018]],
#
#        [[1598, 1017]]], dtype=int32), array([[[1579, 1017]],
#
#        [[1580, 1018]],
#
#        [[1580, 1019]],
#
#        [[1581, 1019]],
#
#        [[1581, 1018]],
#
#        [[1580, 1018]]], dtype=int32), array([[[1506, 1017]]], dtype=int32), array([[[1237, 1017]],
#
#        [[1237, 1024]]], dtype=int32), array([[[1188, 1017]]], dtype=int32), array([[[1086, 1017]]], dtype=int32), array([[[ 652, 1017]],
#
#        [[ 652, 1018]],
#
#        [[ 650, 1020]],
#
#        [[ 652, 1018]]], dtype=int32), array([[[1381, 1016]],
#
#        [[1380, 1017]],
#
#        [[1380, 1018]],
#
#        [[1381, 1019]],
#
#        [[1381, 1021]],
#
#        [[1382, 1022]],
#
#        [[1383, 1021]],
#
#        [[1383, 1020]],
#
#        [[1382, 1019]],
#
#        [[1382, 1017]]], dtype=int32), array([[[1089, 1016]]], dtype=int32), array([[[1461, 1015]],
#
#        [[1461, 1016]],
#
#        [[1458, 1019]],
#
#        [[1458, 1020]],
#
#        [[1457, 1021]],
#
#        [[1457, 1022]],
#
#        [[1456, 1023]],
#
#        [[1455, 1023]],
#
#        [[1454, 1024]],
#
#        [[1454, 1026]],
#
#        [[1456, 1026]],
#
#        [[1456, 1025]],
#
#        [[1457, 1024]],
#
#        [[1457, 1023]],
#
#        [[1459, 1021]],
#
#        [[1459, 1020]],
#
#        [[1460, 1019]],
#
#        [[1460, 1018]],
#
#        [[1462, 1016]],
#
#        [[1462, 1015]]], dtype=int32), array([[[1294, 1015]],
#
#        [[1294, 1017]],
#
#        [[1295, 1016]]], dtype=int32), array([[[ 556, 1015]]], dtype=int32), array([[[1574, 1014]],
#
#        [[1574, 1015]],
#
#        [[1575, 1015]],
#
#        [[1576, 1016]],
#
#        [[1575, 1015]],
#
#        [[1575, 1014]]], dtype=int32), array([[[1530, 1014]],
#
#        [[1532, 1016]]], dtype=int32), array([[[1402, 1014]],
#
#        [[1401, 1015]],
#
#        [[1395, 1015]],
#
#        [[1396, 1016]],
#
#        [[1397, 1016]],
#
#        [[1398, 1015]],
#
#        [[1399, 1016]],
#
#        [[1400, 1015]],
#
#        [[1401, 1016]],
#
#        [[1402, 1016]],
#
#        [[1403, 1017]],
#
#        [[1401, 1019]],
#
#        [[1401, 1020]],
#
#        [[1403, 1018]],
#
#        [[1404, 1018]],
#
#        [[1405, 1017]],
#
#        [[1405, 1015]],
#
#        [[1404, 1016]]], dtype=int32), array([[[ 804, 1014]]], dtype=int32), array([[[ 654, 1014]]], dtype=int32), array([[[ 651, 1014]]], dtype=int32), array([[[ 647, 1014]],
#
#        [[ 648, 1014]]], dtype=int32), array([[[1615, 1013]],
#
#        [[1615, 1015]],
#
#        [[1617, 1017]],
#
#        [[1617, 1016]],
#
#        [[1616, 1015]],
#
#        [[1616, 1014]]], dtype=int32), array([[[1602, 1013]]], dtype=int32), array([[[1289, 1013]]], dtype=int32), array([[[ 792, 1013]]], dtype=int32), array([[[1343, 1012]],
#
#        [[1342, 1013]],
#
#        [[1342, 1014]],
#
#        [[1341, 1015]],
#
#        [[1342, 1014]],
#
#        [[1342, 1013]]], dtype=int32), array([[[1559, 1011]]], dtype=int32), array([[[1209, 1011]],
#
#        [[1210, 1012]],
#
#        [[1210, 1011]]], dtype=int32), array([[[ 609, 1011]],
#
#        [[ 609, 1012]],
#
#        [[ 610, 1012]],
#
#        [[ 611, 1011]]], dtype=int32), array([[[ 582, 1011]]], dtype=int32), array([[[ 564, 1011]]], dtype=int32), array([[[1346, 1010]],
#
#        [[1345, 1011]],
#
#        [[1346, 1011]]], dtype=int32), array([[[1188, 1010]]], dtype=int32), array([[[ 819, 1010]],
#
#        [[ 819, 1011]],
#
#        [[ 818, 1012]],
#
#        [[ 816, 1012]],
#
#        [[ 815, 1011]],
#
#        [[ 814, 1011]],
#
#        [[ 813, 1012]],
#
#        [[ 813, 1013]],
#
#        [[ 810, 1016]],
#
#        [[ 805, 1011]],
#
#        [[ 800, 1011]],
#
#        [[ 799, 1012]],
#
#        [[ 797, 1012]],
#
#        [[ 795, 1014]],
#
#        [[ 795, 1017]],
#
#        [[ 794, 1018]],
#
#        [[ 793, 1018]],
#
#        [[ 793, 1019]],
#
#        [[ 795, 1017]],
#
#        [[ 795, 1016]],
#
#        [[ 797, 1014]],
#
#        [[ 798, 1014]],
#
#        [[ 799, 1015]],
#
#        [[ 799, 1014]],
#
#        [[ 798, 1013]],
#
#        [[ 800, 1011]],
#
# ...
#
#        [[1137,  600]],
#
#        [[1142,  600]],
#
#        [[1143,  601]],
#
#        [[1144,  601]],
#
#        [[1143,  601]],
#
#        [[1142,  600]],
#
#        [[1140,  600]],
#
#        [[1139,  599]],
#
#        [[1136,  599]],
#
#        [[1135,  598]]], dtype=int32), array([[[246, 597]],
#
#        [[246, 598]]], dtype=int32), array([[[297, 594]],
#
#        [[296, 595]],
#
#        [[295, 595]],
#
#        [[295, 598]],
#
#        [[297, 596]]], dtype=int32), array([[[293, 593]]], dtype=int32), array([[[281, 592]],
#
#        [[281, 593]],
#
#        [[283, 595]],
#
#        [[283, 598]],
#
#        [[284, 598]],
#
#        [[285, 599]],
#
#        [[285, 600]],
#
#        [[287, 598]],
#
#        [[287, 597]],
#
#        [[286, 596]],
#
#        [[286, 595]],
#
#        [[285, 596]],
#
#        [[284, 595]],
#
#        [[283, 595]],
#
#        [[282, 594]],
#
#        [[282, 593]]], dtype=int32), array([[[298, 589]]], dtype=int32), array([[[277, 589]],
#
#        [[276, 590]],
#
#        [[276, 591]],
#
#        [[275, 592]],
#
#        [[275, 593]],
#
#        [[276, 592]],
#
#        [[276, 591]],
#
#        [[277, 590]]], dtype=int32), array([[[958, 587]]], dtype=int32), array([[[282, 586]],
#
#        [[282, 587]]], dtype=int32), array([[[956, 584]],
#
#        [[956, 585]]], dtype=int32), array([[[309, 583]],
#
#        [[309, 585]],
#
#        [[310, 585]],
#
#        [[310, 583]]], dtype=int32), array([[[1139,  582]]], dtype=int32), array([[[286, 582]],
#
#        [[285, 583]],
#
#        [[285, 587]],
#
#        [[285, 586]],
#
#        [[286, 585]],
#
#        [[288, 585]],
#
#        [[289, 586]],
#
#        [[287, 588]],
#
#        [[288, 589]],
#
#        [[288, 591]],
#
#        [[290, 591]],
#
#        [[290, 587]],
#
#        [[289, 586]],
#
#        [[289, 583]],
#
#        [[288, 583]],
#
#        [[287, 582]]], dtype=int32), array([[[964, 581]],
#
#        [[964, 582]],
#
#        [[965, 582]],
#
#        [[965, 581]]], dtype=int32), array([[[244, 580]],
#
#        [[244, 581]]], dtype=int32), array([[[278, 577]],
#
#        [[277, 578]],
#
#        [[277, 579]],
#
#        [[277, 578]]], dtype=int32), array([[[281, 575]],
#
#        [[281, 576]]], dtype=int32), array([[[277, 569]],
#
#        [[277, 570]],
#
#        [[276, 571]],
#
#        [[276, 573]],
#
#        [[278, 573]],
#
#        [[278, 571]],
#
#        [[277, 570]]], dtype=int32), array([[[270, 567]]], dtype=int32), array([[[482, 565]],
#
#        [[483, 566]],
#
#        [[483, 565]]], dtype=int32), array([[[275, 565]],
#
#        [[274, 566]],
#
#        [[274, 568]],
#
#        [[274, 567]],
#
#        [[275, 566]]], dtype=int32), array([[[1127,  561]],
#
#        [[1128,  561]]], dtype=int32), array([[[291, 560]]], dtype=int32), array([[[271, 555]]], dtype=int32), array([[[1119,  551]]], dtype=int32), array([[[482, 549]],
#
#        [[483, 550]],
#
#        [[484, 550]],
#
#        [[483, 549]]], dtype=int32), array([[[267, 548]],
#
#        [[264, 551]],
#
#        [[264, 553]],
#
#        [[265, 553]],
#
#        [[267, 555]],
#
#        [[267, 551]],
#
#        [[266, 550]],
#
#        [[266, 549]]], dtype=int32), array([[[261, 544]],
#
#        [[260, 545]],
#
#        [[259, 545]],
#
#        [[260, 545]],
#
#        [[261, 546]],
#
#        [[261, 548]],
#
#        [[262, 548]],
#
#        [[262, 544]]], dtype=int32), array([[[519, 542]]], dtype=int32), array([[[485, 542]]], dtype=int32), array([[[257, 542]],
#
#        [[256, 543]],
#
#        [[256, 545]],
#
#        [[257, 545]]], dtype=int32), array([[[1107,  540]]], dtype=int32), array([[[518, 537]],
#
#        [[517, 538]],
#
#        [[516, 538]],
#
#        [[516, 540]],
#
#        [[515, 541]],
#
#        [[515, 542]],
#
#        [[516, 541]],
#
#        [[517, 541]],
#
#        [[517, 538]],
#
#        [[518, 537]],
#
#        [[519, 537]]], dtype=int32), array([[[233, 536]],
#
#        [[234, 536]]], dtype=int32), array([[[496, 535]],
#
#        [[496, 536]],
#
#        [[497, 536]]], dtype=int32), array([[[267, 533]],
#
#        [[268, 534]],
#
#        [[268, 533]]], dtype=int32), array([[[231, 531]],
#
#        [[232, 531]],
#
#        [[233, 532]],
#
#        [[232, 531]]], dtype=int32), array([[[249, 530]],
#
#        [[250, 531]]], dtype=int32), array([[[267, 528]],
#
#        [[267, 530]]], dtype=int32), array([[[248, 526]]], dtype=int32), array([[[313, 524]],
#
#        [[313, 525]]], dtype=int32), array([[[1087,  518]],
#
#        [[1085,  520]]], dtype=int32), array([[[303, 511]],
#
#        [[303, 512]],
#
#        [[302, 513]],
#
#        [[302, 514]],
#
#        [[303, 513]]], dtype=int32), array([[[301, 509]]], dtype=int32), array([[[211, 509]],
#
#        [[209, 511]],
#
#        [[212, 514]],
#
#        [[213, 513]],
#
#        [[213, 512]],
#
#        [[212, 512]],
#
#        [[211, 511]]], dtype=int32), array([[[297, 507]],
#
#        [[298, 508]]], dtype=int32), array([[[259, 507]],
#
#        [[258, 508]],
#
#        [[258, 509]],
#
#        [[259, 510]]], dtype=int32), array([[[188, 507]],
#
#        [[188, 508]]], dtype=int32), array([[[559, 506]],
#
#        [[559, 507]],
#
#        [[560, 508]],
#
#        [[560, 507]]], dtype=int32), array([[[217, 505]],
#
#        [[217, 506]],
#
#        [[218, 506]],
#
#        [[218, 505]]], dtype=int32), array([[[204, 505]],
#
#        [[204, 506]],
#
#        [[205, 505]]], dtype=int32), array([[[559, 504]]], dtype=int32), array([[[166, 504]],
#
#        [[165, 505]],
#
#        [[165, 506]],
#
#        [[165, 505]]], dtype=int32), array([[[209, 503]],
#
#        [[208, 504]],
#
#        [[209, 503]],
#
#        [[210, 504]],
#
#        [[210, 503]]], dtype=int32), array([[[299, 502]]], dtype=int32), array([[[561, 499]],
#
#        [[561, 502]],
#
#        [[562, 502]],
#
#        [[563, 501]],
#
#        [[565, 501]],
#
#        [[565, 499]]], dtype=int32), array([[[196, 499]]], dtype=int32), array([[[292, 497]],
#
#        [[292, 498]],
#
#        [[291, 499]],
#
#        [[292, 498]]], dtype=int32), array([[[300, 495]],
#
#        [[299, 496]],
#
#        [[298, 496]],
#
#        [[300, 498]],
#
#        [[300, 499]],
#
#        [[299, 500]],
#
#        [[298, 499]],
#
#        [[298, 500]],
#
#        [[299, 500]],
#
#        [[300, 499]],
#
#        [[301, 500]],
#
#        [[301, 502]],
#
#        [[302, 503]],
#
#        [[302, 500]],
#
#        [[301, 499]],
#
#        [[301, 496]]], dtype=int32), array([[[305, 487]],
#
#        [[305, 488]]], dtype=int32), array([[[299, 487]]], dtype=int32), array([[[294, 487]],
#
#        [[294, 489]]], dtype=int32), array([[[284, 485]],
#
#        [[284, 487]],
#
#        [[285, 486]],
#
#        [[285, 485]]], dtype=int32), array([[[243, 484]]], dtype=int32), array([[[283, 478]]], dtype=int32), array([[[543, 474]],
#
#        [[542, 475]],
#
#        [[541, 475]],
#
#        [[539, 477]],
#
#        [[538, 477]],
#
#        [[538, 478]],
#
#        [[537, 479]],
#
#        [[536, 479]],
#
#        [[535, 480]],
#
#        [[535, 481]],
#
#        [[534, 482]],
#
#        [[533, 482]],
#
#        [[533, 483]],
#
#        [[532, 484]],
#
#        [[531, 484]],
#
#        [[530, 485]],
#
#        [[530, 486]],
#
#        [[529, 487]],
#
#        [[529, 488]],
#
#        [[531, 488]],
#
#        [[532, 487]],
#
#        [[533, 487]],
#
#        [[533, 486]],
#
#        [[535, 484]],
#
#        [[536, 485]],
#
#        [[536, 483]],
#
#        [[537, 482]],
#
#        [[538, 483]],
#
#        [[538, 484]],
#
#        [[539, 484]],
#
#        [[539, 483]],
#
#        [[540, 482]],
#
#        [[539, 481]],
#
#        [[539, 480]],
#
#        [[540, 479]],
#
#        [[541, 479]],
#
#        [[542, 480]],
#
#        [[542, 479]],
#
#        [[543, 478]],
#
#        [[544, 479]],
#
#        [[543, 478]],
#
#        [[543, 476]],
#
#        [[544, 475]],
#
#        [[544, 474]]], dtype=int32), array([[[205, 474]]], dtype=int32), array([[[259, 470]],
#
#        [[259, 471]]], dtype=int32), array([[[310, 469]],
#
#        [[310, 470]]], dtype=int32), array([[[214, 467]],
#
#        [[213, 468]],
#
#        [[213, 469]],
#
#        [[214, 469]],
#
#        [[215, 468]],
#
#        [[215, 467]]], dtype=int32), array([[[214, 463]],
#
#        [[214, 464]]], dtype=int32), array([[[229, 461]],
#
#        [[228, 462]],
#
#        [[226, 462]],
#
#        [[225, 463]],
#
#        [[225, 464]],
#
#        [[224, 465]],
#
#        [[225, 465]],
#
#        [[226, 464]],
#
#        [[226, 463]],
#
#        [[227, 462]],
#
#        [[229, 464]],
#
#        [[229, 462]],
#
#        [[230, 461]]], dtype=int32), array([[[456, 458]],
#
#        [[456, 459]]], dtype=int32), array([[[270, 457]],
#
#        [[270, 458]]], dtype=int32), array([[[455, 452]],
#
#        [[455, 454]],
#
#        [[456, 455]],
#
#        [[456, 454]],
#
#        [[457, 453]],
#
#        [[457, 452]]], dtype=int32), array([[[216, 451]],
#
#        [[218, 451]]], dtype=int32), array([[[222, 440]],
#
#        [[222, 442]]], dtype=int32), array([[[226, 431]]], dtype=int32), array([[[422, 427]],
#
#        [[422, 430]]], dtype=int32), array([[[420, 424]],
#
#        [[421, 425]],
#
#        [[421, 424]]], dtype=int32), array([[[241, 420]],
#
#        [[240, 421]],
#
#        [[241, 422]],
#
#        [[240, 423]],
#
#        [[241, 423]],
#
#        [[241, 422]],
#
#        [[242, 421]]], dtype=int32), array([[[249, 416]],
#
#        [[249, 418]]], dtype=int32), array([[[300, 411]],
#
#        [[300, 413]],
#
#        [[301, 412]],
#
#        [[301, 411]]], dtype=int32), array([[[238, 406]],
#
#        [[238, 409]],
#
#        [[239, 410]],
#
#        [[239, 412]],
#
#        [[240, 412]],
#
#        [[239, 411]],
#
#        [[239, 409]],
#
#        [[238, 408]],
#
#        [[239, 407]],
#
#        [[240, 407]],
#
#        [[239, 406]]], dtype=int32), array([[[425, 401]],
#
#        [[426, 401]]], dtype=int32), array([[[220, 400]]], dtype=int32), array([[[425, 399]]], dtype=int32), array([[[ 71, 399]],
#
#        [[ 70, 400]],
#
#        [[ 70, 401]],
#
#        [[ 70, 400]]], dtype=int32), array([[[427, 397]]], dtype=int32), array([[[237, 396]],
#
#        [[236, 397]]], dtype=int32), array([[[417, 395]],
#
#        [[417, 396]],
#
#        [[416, 397]],
#
#        [[416, 398]],
#
#        [[416, 397]],
#
#        [[417, 396]],
#
#        [[418, 396]],
#
#        [[419, 397]],
#
#        [[418, 396]],
#
#        [[418, 395]]], dtype=int32), array([[[270, 395]]], dtype=int32), array([[[241, 394]],
#
#        [[240, 395]],
#
#        [[240, 397]],
#
#        [[239, 398]],
#
#        [[239, 400]],
#
#        [[240, 400]],
#
#        [[242, 398]],
#
#        [[242, 395]]], dtype=int32), array([[[287, 393]],
#
#        [[287, 394]],
#
#        [[288, 394]]], dtype=int32), array([[[298, 390]],
#
#        [[297, 391]],
#
#        [[296, 391]],
#
#        [[296, 394]],
#
#        [[297, 395]],
#
#        [[297, 396]],
#
#        [[296, 397]],
#
#        [[296, 399]],
#
#        [[296, 397]],
#
#        [[298, 395]],
#
#        [[297, 394]],
#
#        [[297, 393]],
#
#        [[298, 392]]], dtype=int32), array([[[908, 379]]], dtype=int32), array([[[290, 379]],
#
#        [[291, 379]],
#
#        [[292, 380]],
#
#        [[291, 381]],
#
#        [[291, 382]],
#
#        [[292, 382]],
#
#        [[293, 381]],
#
#        [[293, 380]],
#
#        [[292, 379]]], dtype=int32), array([[[465, 375]],
#
#        [[465, 380]],
#
#        [[465, 378]],
#
#        [[466, 377]],
#
#        [[466, 375]]], dtype=int32), array([[[426, 374]],
#
#        [[426, 376]],
#
#        [[427, 377]],
#
#        [[427, 375]]], dtype=int32), array([[[231, 373]]], dtype=int32), array([[[732, 365]],
#
#        [[731, 366]],
#
#        [[730, 366]],
#
#        ...,
#
#        [[737, 366]],
#
#        [[735, 366]],
#
#        [[734, 365]]], dtype=int32), array([[[185, 328]]], dtype=int32), array([[[412, 327]]], dtype=int32), array([[[217, 321]],
#
#        [[217, 322]]], dtype=int32), array([[[478, 304]],
#
#        [[478, 305]],
#
#        [[476, 307]],
#
#        [[476, 316]],
#
#        [[477, 315]],
#
#        [[478, 315]],
#
#        [[478, 314]],
#
#        [[477, 313]],
#
#        [[478, 312]]], dtype=int32), array([[[392, 283]]], dtype=int32), array([[[414, 268]]], dtype=int32), array([[[406, 237]],
#
#        [[405, 238]],
#
#        [[405, 241]],
#
#        [[406, 240]]], dtype=int32), array([[[196, 233]],
#
#        [[196, 234]],
#
#        [[197, 234]],
#
#        [[197, 233]]], dtype=int32), array([[[401, 231]],
#
#        [[401, 232]],
#
#        [[399, 234]],
#
#        [[400, 233]],
#
#        [[403, 233]],
#
#        [[403, 232]],
#
#        [[402, 232]]], dtype=int32), array([[[171, 223]]], dtype=int32), array([[[363, 218]],
#
#        [[364, 219]],
#
#        [[364, 218]]], dtype=int32), array([[[399, 213]],
#
#        [[399, 217]],
#
#        [[400, 218]],
#
#        [[401, 218]],
#
#        [[401, 214]],
#
#        [[400, 214]]], dtype=int32), array([[[396, 205]]], dtype=int32), array([[[400, 204]],
#
#        [[400, 207]],
#
#        [[401, 206]],
#
#        [[400, 205]]], dtype=int32), array([[[402, 192]]], dtype=int32), array([[[398, 162]],
#
#        [[397, 163]],
#
#        [[396, 163]],
#
#        [[396, 164]],
#
#        [[397, 165]],
#
#        [[396, 166]],
#
#        [[395, 166]],
#
#        [[395, 170]],
#
#        [[397, 172]],
#
#        [[397, 173]],
#
#        [[398, 174]],
#
#        [[399, 174]],
#
#        [[400, 175]],
#
#        [[400, 176]],
#
#        [[401, 177]],
#
#        [[401, 184]],
#
#        [[400, 185]],
#
#        [[399, 185]],
#
#        [[400, 186]],
#
#        [[400, 189]],
#
#        [[401, 189]],
#
#        [[403, 187]],
#
#        [[402, 186]],
#
#        [[402, 185]],
#
#        [[403, 184]],
#
#        [[403, 181]],
#
#        [[404, 180]],
#
#        [[404, 177]],
#
#        [[403, 177]],
#
#        [[402, 176]],
#
#        [[404, 174]],
#
#        [[404, 172]],
#
#        [[405, 171]],
#
#        [[404, 170]],
#
#        [[404, 169]],
#
#        [[403, 169]],
#
#        [[402, 168]],
#
#        [[401, 168]],
#
#        [[398, 165]]], dtype=int32), array([[[391, 141]]], dtype=int32), array([[[386, 140]],
#
#        [[386, 141]]], dtype=int32), array([[[389, 135]],
#
#        [[390, 135]]], dtype=int32), array([[[394, 132]],
#
#        [[393, 133]],
#
#        [[393, 137]],
#
#        [[395, 139]],
#
#        [[395, 140]],
#
#        [[396, 140]],
#
#        [[397, 141]],
#
#        [[396, 142]],
#
#        [[395, 142]],
#
#        [[395, 144]],
#
#        [[394, 145]],
#
#        [[392, 145]],
#
#        [[393, 146]],
#
#        [[395, 146]],
#
#        [[396, 147]],
#
#        [[395, 148]],
#
#        [[395, 156]],
#
#        [[396, 157]],
#
#        [[396, 158]],
#
#        [[397, 159]],
#
#        [[396, 160]],
#
#        [[396, 161]],
#
#        [[398, 159]],
#
#        [[398, 158]],
#
#        [[401, 155]],
#
#        [[400, 155]],
#
#        [[399, 154]],
#
#        [[399, 153]],
#
#        [[400, 152]],
#
#        [[399, 152]],
#
#        [[398, 151]],
#
#        [[398, 143]],
#
#        [[397, 142]],
#
#        [[397, 141]],
#
#        [[396, 140]],
#
#        [[397, 139]],
#
#        [[395, 137]],
#
#        [[396, 136]],
#
#        [[397, 136]],
#
#        [[396, 136]],
#
#        [[395, 135]],
#
#        [[396, 134]],
#
#        [[396, 133]],
#
#        [[395, 132]]], dtype=int32), array([[[384, 129]],
#
#        [[384, 130]],
#
#        [[385, 130]],
#
#        [[386, 131]],
#
#        [[386, 132]],
#
#        [[387, 133]],
#
#        [[387, 130]],
#
#        [[386, 130]],
#
#        [[385, 129]]], dtype=int32), array([[[386, 125]],
#
#        [[386, 126]]], dtype=int32), array([[[392, 121]],
#
#        [[392, 123]],
#
#        [[393, 124]],
#
#        [[393, 129]],
#
#        [[394, 130]],
#
#        [[394, 129]],
#
#        [[393, 128]],
#
#        [[394, 127]],
#
#        [[394, 126]],
#
#        [[393, 125]],
#
#        [[397, 121]],
#
#        [[396, 122]],
#
#        [[395, 122]],
#
#        [[394, 123]],
#
#        [[393, 123]],
#
#        [[392, 122]]], dtype=int32), array([[[392, 114]],
#
#        [[393, 115]]], dtype=int32), array([[[393, 104]]], dtype=int32), array([[[391, 104]]], dtype=int32), array([[[393,  95]],
#
#        [[390,  98]],
#
#        [[390,  99]],
#
#        [[389, 100]],
#
#        [[389, 101]],
#
#        [[390, 102]],
#
#        [[390,  99]],
#
#        [[393,  96]]], dtype=int32), array([[[387,  95]],
#
#        [[388,  96]]], dtype=int32), array([[[386,  89]],
#
#        [[387,  89]]], dtype=int32), array([[[392,  87]],
#
#        [[391,  88]],
#
#        [[389,  88]],
#
#        [[389,  89]],
#
#        [[392,  89]],
#
#        [[393,  88]],
#
#        [[394,  88]],
#
#        [[394,  87]]], dtype=int32), array([[[345,  81]]], dtype=int32), array([[[387,  78]]], dtype=int32), array([[[388,  69]]], dtype=int32), array([[[386,  62]],
#
#        [[386,  64]],
#
#        [[386,  63]],
#
#        [[387,  62]]], dtype=int32), array([[[313,  56]]], dtype=int32), array([[[381,  52]],
#
#        [[381,  53]]], dtype=int32), array([[[382,  43]],
#
#        [[382,  44]],
#
#        [[380,  46]],
#
#        [[381,  46]],
#
#        [[382,  45]],
#
#        [[382,  44]],
#
#        [[383,  43]]], dtype=int32), array([[[380,  39]],
#
#        [[378,  41]],
#
#        [[378,  42]],
#
#        [[379,  42]],
#
#        [[379,  41]],
#
#        [[380,  40]]], dtype=int32))
# 1
