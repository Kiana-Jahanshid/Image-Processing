# %%
import cv2 
import numpy as np 
import matplotlib.pyplot as plt

# %%
img = cv2.imread("Assignment_36/inputs/b.jpg")
img = cv2.cvtColor(img , cv2.COLOR_BGR2RGB)
plt.imshow(img)

img1 = cv2.cvtColor(img , cv2.COLOR_BGR2HSV)
H , S , V = cv2.split(img1)
H_new = H.copy().astype(np.float32)

# %%
for i in range(H.shape[0]):
    for j in range(H.shape[1]): 

        # if 45 < H[i,j] < 65  : # green 
        #     img[i,j] ==  img[i,j]
        # else :
        #     img[i,j]= 0

        # if 125 < H[i,j] < 170  : # purple 
        #     img[i,j] ==  img[i,j]
        # else :
        #     img[i,j]= 0  

        if 122 < H[i,j] < 140  :  # pink 
            img[i,j] ==  img[i,j]
        else :
            img[i,j]= 0 

H_new = H_new.astype(np.uint8)
result = cv2.merge((H_new,S,V))
result = cv2.cvtColor(result , cv2.COLOR_HSV2RGB)

plt.imshow(img)
