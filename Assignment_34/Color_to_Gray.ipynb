# %%
import cv2
import numpy as np 
import matplotlib.pyplot as plt

# %%
color = cv2.imread("Assignment_34\inputs\COLOR.jpg")
watermelon = cv2.cvtColor(color , cv2.COLOR_BGR2RGB)
plt.imshow(color)

# %%
def color_to_grayscale(R,G,B):
    Grayscale = (R + G + B / 3)
    return Grayscale


R , G , B  = cv2.split(watermelon)
Grayscale = color_to_grayscale(R,G,B)

cv2.imwrite("gray.jpg" , Grayscale)
plt.imshow(Grayscale , cmap="gray")
